# %% [markdown]
# ## Feature Engineering - Handling Missing Values
#
# **Missing values** are instances where data points that should be present in a dataset are either not recorded or unavailable. They occur when no data value is stored for a variable in an observation.
#
# ### Types of Missing Data:
# **1.	Missing Completely at Random (MCAR):** The missingness is entirely random and unrelated to any observed or unobserved data.
# **2.	Missing at Random (MAR):** The missingness depends on observed data but not on the missing data itself.
# **3.	Missing Not at Random (MNAR):** The missingness depends on the unobserved (missing) data itself.
#
# ### Common Causes of Missing Data:
# •	Data entry errors.
# •	Non-response in surveys or questionnaires.
# •	Equipment failures during data collection.
# •	Data corruption or loss.
# •	Intentional omissions (e.g., sensitive questions skipped by respondents).
#
# ### Impact of Missing Values:
# •	Reduces the completeness and reliability of the dataset.
# •	Affects statistical analysis and model performance.
# •	Can lead to biased conclusions if not handled appropriately.
#
# ### Why Handle Missing Values?
# **1.	Avoid Bias:** Missing values can lead to biased results, especially if the missingness is not random (e.g., MAR or MNAR).
# **2.	Improve Model Performance:** Most machine learning algorithms cannot handle missing data, and proper handling ensures better predictions and accuracy.
# **3.	Preserve Data Integrity:** Missing values can distort statistical measures like mean, variance, and correlations, leading to incorrect conclusions.
# **4.	Maximize Data Utilization:** Handling missing values prevents significant data loss from deletion methods, ensuring the dataset retains its full potential.
# **5.	Ensure Analytical Compatibility:** Many statistical and machine learning methods require complete data, so addressing missing values is essential for their proper functioning.

# %% [markdown]
# ## How To Handle Missing Values?
#
# ### 1. Deletion Methods: Remove rows or columns with missing values.
# •	Pros: Simple, no assumptions required.
# •	Cons: Loss of data, reduced sample size.
# •	When to apply: When missing data is minimal (<5%) and randomly distributed (MCAR).
#
# ### 2. Imputation Methods:
# **Mean/Median/Mode Imputation:**  Replace missing values with the mean (for both normal and skewed distribution) , median (for skewed distribution), or mode (for categorical variable).
# •	Pros: Easy to implement, fast.
# •	Cons: Distorts data distribution, ignores variability, introduce outliers.
# •	When to apply: When missing data is small and data distribution is uniform.
#
# **Forward/Backward Filling:** Fill missing values with the previous (forward) or next (backward) available value.
# •	Pros: Works well for time-series data.
# •	Cons: Assumes continuity, not suitable for abrupt changes.
# •	When to apply: For sequential or time-series datasets.
#
# **Arbitrary Value Imputation:** Replace missing values with a fixed, arbitrary number (e.g., -999/1/0 in case of numerical variable) or values (NA in case of categorical variable).
# •	Pros: Simple, preserves missingness as identifiable.
# •	Cons: Can distort relationships and metrics, finding perfect number/text.
# •	When to apply: When missing values are meaningful or require clear identification.
#
# **Linear Interpolation:** Estimate missing values by interpolating between known values.
# •	Pros: Maintains data trends.
# •	Cons: Assumes linear relationships, unsuitable for non-linear data.
# •	When to apply: For continuous data with predictable trends.
#
# **End of Distribution Imputation (Applicable for Numeric variable):** Replace missing values with extreme values (e.g., min or max).
# •	Pros: Captures uniqueness of missingness.
# •	Cons: Can distort metrics and relationships.
# •	When to apply: For outlier detection or when missing values indicate extreme cases.
#
# **Multiple Imputation:** Generate multiple plausible imputed datasets and combine results.
# •	Pros: Accounts for uncertainty, statistically robust.
# •	Cons: Computationally intensive, requires expertise.
# •	When to apply: For large datasets with MAR or MCAR missingness.
#
# **Regression Imputation:** Predict missing values using a regression model.
# •	Pros: Utilizes relationships among variables.
# •	Cons: Assumes linearity, may introduce bias.
# •	When to apply: When strong relationships exist between variables.
#
# ### 3. Model-Based Methods
# **Decision Trees (e.g., Random Forest)** Use decision trees to predict and impute missing values.
# •	Pros: Captures non-linear relationships, works for mixed data types.
# •	Cons: Computationally expensive, risk of overfitting.
# •	When to apply: For complex datasets with non-linear dependencies.
#
# **k-Nearest Neighbours (KNN)** Impute values using the mean/mode of similar data points (neighbours).
# •	Pros: Flexible, works well with structured data.
# •	Cons: Computationally heavy for large datasets.
# •	When to apply: When clear local patterns exist in the data.
#
# ### 4. Other Methods:
# **Using Indicator Variables for Missingness:** Add binary columns to indicate missing values.
# •	Pros: Retains missingness information, prevents data loss.
# •	Cons: Increases dataset complexity, may overfit.
# •	When to apply: When missingness itself is meaningful or informative (e.g., MNAR scenarios).

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## Sample Datasets 
titanic = pd.read_csv ("C:\\Users\\BINPAT\\Documents\\Python Self\\Feature Engineering\\Datasets\\train.csv")

# %% [markdown]
# before imputing missing values let's see how to find missing values inside dataset.

# %% [markdown]
# ## **Checking For Missing Values Inside The Dataset**

# %%
## 1. Using isna() or isnull() To Find Count
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
## 2. Missing Values Percentage
round((titanic.isna().sum() / len(titanic))*100,2)
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Name            0.00
# Sex             0.00
# Age            19.87
# SibSp           0.00
# Parch           0.00
# Ticket          0.00
# Fare            0.00
# Cabin          77.10
# Embarked        0.22
# dtype: float64

# %%
## 3. Visulizing Missing Values
import missingno as mn
mn.matrix(titanic,figsize=(10,8));

# %% [markdown]
# # How To Handle Missing Values?

# %% [markdown]
# There are two ways to handle missing values-
# 1. Dropping Missing Values
# 2. Imputing Missing Values With Some Other Value (Preferred)

# %% [markdown]
# ### 1. Dropping Missing Values
# * if missing values is of type Missing At Random(MAR) or Missing Completly At Random(MCAR) then it can be deleted.
# * One of the biggest disadvantage of dropping missing values is one might end up deleting some useful data as well with missing values.
#
# There are two ways to remove missing values
# 1. Deleting the entire row containing missing values
# 2. Deleting the entire column containing missing values

# %% [markdown]
# #### 1. Deleting The Entire Row

# %%
## Copy of data
df = titanic.copy()
df = df.dropna(axis=0)
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
print('Dataset Size With Missing Values',titanic.shape)
# Out:
# Dataset Size With Missing Values (891, 12)

# %%
print('Dataset Size Without Missing Values',df.shape)
# Out:
# Dataset Size Without Missing Values (183, 12)

# %% [markdown]
# There is a big loss of data, because Cabin column contains more than 75% missing values.

# %% [markdown]
# #### 2. Deleting The Entire Column

# %%
## Copy of data
df = titanic.copy()
df = df.drop(['Cabin','Age','Embarked'],axis=1) 
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# dtype: int64

# %% [markdown]
# Although We Have Removed Missing Values, But With Them a big part of data is also lost. Like Age is a very important column for survival of a person.

# %% [markdown]
# > Deleting Missing Values From The Dataset Is Only An Option if we have less than 10% of missing values on a big dataset.
#
# The Best and Evergreen option is to Impute missing values with some other similar value.

# %% [markdown]
# ## 2. Imputing Missing Values

# %% [markdown]
# ## METHOD 1 → Mean Value Imputation

# %% [markdown]
# In this technique we replace missing values with the `mean` value of the column containing missing values

# %%
## First Step : Check The Distribution
sns.distplot(titanic.Age);
# Out:
# C:\Users\BINPAT\AppData\Local\Temp\ipykernel_7100\3050056627.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic.Age);

# %%
def impute_nan_mean(df,column,mean):
    df[column+'_mean'] = df[column].fillna(mean)
    return df

mean_val = titanic.Age.mean()
titanic = impute_nan_mean(titanic,'Age',mean_val)

# %%
titanic[titanic.Age.isna()][['Age','Age_mean']]
# Out:
#      Age   Age_mean
# 5    NaN  29.699118
# 17   NaN  29.699118
# 19   NaN  29.699118
# 26   NaN  29.699118
# 28   NaN  29.699118
# ..   ...        ...
# 859  NaN  29.699118
# 863  NaN  29.699118
# 868  NaN  29.699118
# 878  NaN  29.699118
# 888  NaN  29.699118
#
# [177 rows x 2 columns]

# %% [markdown]
# Mean Imputation is a great choice, if distribution is normal or close to normal.
#
# In case of skewed distribution we shoud go with meadian value.

# %% [markdown]
# ## METHOD 2: Median Value Imputation
#
# In this technique we replace all the missing value with median value of the column

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked   Age_mean
# 0        0         A/5 21171   7.2500   NaN        S  22.000000
# 1        0          PC 17599  71.2833   C85        C  38.000000
# 2        0  STON/O2. 3101282   7.9250   NaN        S  26.000000
# 3        0            113803  53.1000  C123        S  35.000000
# 4        0            373450   8.0500   NaN        S  35.000000
# ..     ...               ...      ...   ...      ...        ...
# 886      0            211536  13.0000   NaN        S  27.000000
# 887      0            112053  30.0000   B42        S  19.000000
# 888      2        W./C. 6607  23.4500   NaN        S  29.699118
# 889      0            111369  30.0000  C148        C  26.000000
# 890      0            370376   7.7500   NaN        Q  32.000000
#
# [891 rows x 13 columns]

# %%
## Imputing missing value with median value of the column
def impute_nan_median(df,column,median):
    df[column+'_median'] = df[column].fillna(median)
    return df

median_val = titanic.Age.median()
titanic = impute_nan_median(titanic,'Age',median_val)

# %%
titanic[titanic.Age.isna()][['Age','Age_median']]
# Out:
#      Age  Age_median
# 5    NaN        28.0
# 17   NaN        28.0
# 19   NaN        28.0
# 26   NaN        28.0
# 28   NaN        28.0
# ..   ...         ...
# 859  NaN        28.0
# 863  NaN        28.0
# 868  NaN        28.0
# 878  NaN        28.0
# 888  NaN        28.0
#
# [177 rows x 2 columns]

# %% [markdown]
# ## METHOD 3: Mode Imputation (Frequent Category Imputation)
#
# Mode value imputation is mostly used for categorical data. it can also be used for numerical variables as well.
#
# * In this technique we replace all the missing values with the most frequent value of the column.

# %%
## Imputing missing value with median value of the column
def impute_nan_mode(df,column,mode):
    df[column+'_mode'] = df[column].fillna(mode)
    return df

mode_val = titanic.Age.mode()
titanic = impute_nan_mode(titanic,'Age',mode_val)

# %%
titanic[titanic.Age.isna()][['Age','Age_mode']]
# Out:
#      Age  Age_mode
# 5    NaN       NaN
# 17   NaN       NaN
# 19   NaN       NaN
# 26   NaN       NaN
# 28   NaN       NaN
# ..   ...       ...
# 859  NaN       NaN
# 863  NaN       NaN
# 868  NaN       NaN
# 878  NaN       NaN
# 888  NaN       NaN
#
# [177 rows x 2 columns]

# %% [markdown]
# you see how most NAN values gets replaced with NAN values because the most frequent value of this numerical column is `NAN`. To use mode here we need to ignore all the NAN values and then apply mode on remaining values.

# %%
titanic[titanic.Age.notna()]['Age'].mode()[0]
# Out:
# 24.0

# %%
## Imputing missing value with median value of the column
def impute_nan_mode(df,column,mode):
    df[column+'_mode'] = df[column].fillna(mode)
    return df

mode_val = titanic[titanic.Age.notna()]['Age'].mode()[0]    ## find mode of all the non missing values of Age column
titanic = impute_nan_mode(titanic,'Age',mode_val)

# %%
titanic[titanic.Age.isna()][['Age','Age_mode']]
# Out:
#      Age  Age_mode
# 5    NaN      24.0
# 17   NaN      24.0
# 19   NaN      24.0
# 26   NaN      24.0
# 28   NaN      24.0
# ..   ...       ...
# 859  NaN      24.0
# 863  NaN      24.0
# 868  NaN      24.0
# 878  NaN      24.0
# 888  NaN      24.0
#
# [177 rows x 2 columns]

# %% [markdown]
# Although the above code worked but you should never use mode for a numerical column until there is some exception.
#
# Mode works better for categorical data with less categories.
#
# * One of the biggest advantage of using mode as categorical data imputer is that we don't need to convert categories into numerical data.
#
# Let's use it to fill missing values in Embarked Column.

# %%
titanic.Embarked.isna().sum()
# Out:
# 2

# %%
#### STEP 1: Find Mode Values
mode_cat_embarked = titanic.Embarked.mode()[0]

#### STEP 2: Fill Missing Values With Most Frequent Category
titanic['Embarked_mode'] = titanic['Embarked'].fillna(mode_cat_embarked)

#### Check For Results
titanic['Embarked_mode'].isna().sum()
# Out:
# 0

# %%
mode_cat_embarked
# Out:
# 'S'

# %% [markdown]
# ## METHOD 4:  Random Sample Imputation
#
# In this method we will replace all the missing values with  a random sample from the data.

# %%
### STEP 1: Generating Random Sample
sample = titanic.Age.sample().values[0]

### STEP 2: Filling nan values with random sample value
titanic['Age'+'_random_sample'] = titanic['Age'].fillna(sample)

titanic[titanic['Age'].isna()][['Age','Age_random_sample']]
# Out:
#      Age  Age_random_sample
# 5    NaN               19.0
# 17   NaN               19.0
# 19   NaN               19.0
# 26   NaN               19.0
# 28   NaN               19.0
# ..   ...                ...
# 859  NaN               19.0
# 863  NaN               19.0
# 868  NaN               19.0
# 878  NaN               19.0
# 888  NaN               19.0
#
# [177 rows x 2 columns]

# %%
### STEP 1: Generating Random Sample
sample = titanic.Age.sample().values[0]

### STEP 2: Filling nan values with random sample value
titanic['Age'+'_random_sample'] = titanic['Age'].fillna(sample)

titanic[titanic['Age'].isna()][['Age','Age_random_sample']]
# Out:
#      Age  Age_random_sample
# 5    NaN               27.0
# 17   NaN               27.0
# 19   NaN               27.0
# 26   NaN               27.0
# 28   NaN               27.0
# ..   ...                ...
# 859  NaN               27.0
# 863  NaN               27.0
# 868  NaN               27.0
# 878  NaN               27.0
# 888  NaN               27.0
#
# [177 rows x 2 columns]

# %% [markdown]
# You see everytime we run the codeblock we get a new random sample value.
#
# To avoid this we can make use of `np.seed()`
#
# * Note: There are chances that our random sample will pick nan as a sample, to avoid this we can use the same method we have used in mode.

# %%
import numpy as np
np.random.seed(42)

### STEP 1: Generating Random Sample
sample = titanic[titanic.Age.notna()]['Age'].sample().values[0]

### STEP 2: Filling nan values with random sample value
titanic['Age'+'_random_sample'] = titanic['Age'].fillna(sample)

titanic[titanic['Age'].isna()][['Age','Age_random_sample']]
# Out:
#      Age  Age_random_sample
# 5    NaN               42.0
# 17   NaN               42.0
# 19   NaN               42.0
# 26   NaN               42.0
# 28   NaN               42.0
# ..   ...                ...
# 859  NaN               42.0
# 863  NaN               42.0
# 868  NaN               42.0
# 878  NaN               42.0
# 888  NaN               42.0
#
# [177 rows x 2 columns]

# %% [markdown]
# no matter how many time we run the above codeblock the value will remain same, until whole execution resets.

# %% [markdown]
# ## METHOD 5: End of Distribution

# %% [markdown]
# If Missing Value is not at random then we can use this method.  In this we replace all the missing values with 3rd std deviation value

# %%
sns.boxplot(x = 'Age',data=titanic);

# %%
### STEP 1: Find Extreme Value
extreme = titanic.Age.mean() + 3*titanic.Age.std()

### STEP 2: Fill nan with extreme value
titanic['Age_end_distribution']  = titanic['Age'].fillna(extreme)

titanic
titanic[titanic['Age'].isna()][['Age','Age_end_distribution']]
# Out:
#      Age  Age_end_distribution
# 5    NaN              73.27861
# 17   NaN              73.27861
# 19   NaN              73.27861
# 26   NaN              73.27861
# 28   NaN              73.27861
# ..   ...                   ...
# 859  NaN              73.27861
# 863  NaN              73.27861
# 868  NaN              73.27861
# 878  NaN              73.27861
# 888  NaN              73.27861
#
# [177 rows x 2 columns]

# %% [markdown]
# we can also use a least value based on our data distribution.

# %% [markdown]
# #### In all above methods we are replacing missing values with some other value from the sample.
# What if missing values are not at random?
#
# What if you are required to showcase the importance of missing values?
#
# In all above and similar cases we can use Arbitrary Value Imputation.

# %% [markdown]
# ## METHOD 6.1: Arbitrary Value Imputation (Numerical)
#
# In this method we replace missing value with lowest or highest value of the distribution. (-infinity, +infinity)
#
# In case of Age we can replace missing values either with 0 or 100.(least and highest)
#
# * This method not only fill missing values but also captures the importance of it.

# %%
### Filling Values using 0
titanic['Age_0'] = titanic['Age'].fillna(0)

# %%
### Filling Values using 100
titanic['Age_100'] = titanic['Age'].fillna(100)

# %%
titanic[titanic.Age.isna()][['Age','Age_0','Age_100']]
# Out:
#      Age  Age_0  Age_100
# 5    NaN    0.0    100.0
# 17   NaN    0.0    100.0
# 19   NaN    0.0    100.0
# 26   NaN    0.0    100.0
# 28   NaN    0.0    100.0
# ..   ...    ...      ...
# 859  NaN    0.0    100.0
# 863  NaN    0.0    100.0
# 868  NaN    0.0    100.0
# 878  NaN    0.0    100.0
# 888  NaN    0.0    100.0
#
# [177 rows x 3 columns]

# %% [markdown]
# ## METHOD 6.2: Arbitrary Value Imputation (Categorical)

# %%
titanic['Cabin_Missing'] = titanic['Cabin'].fillna('Missing')

# %%
titanic[titanic.Cabin.isna()][['Cabin','Cabin_Missing']]
# Out:
#     Cabin Cabin_Missing
# 0     NaN       Missing
# 2     NaN       Missing
# 4     NaN       Missing
# 5     NaN       Missing
# 7     NaN       Missing
# ..    ...           ...
# 884   NaN       Missing
# 885   NaN       Missing
# 886   NaN       Missing
# 888   NaN       Missing
# 890   NaN       Missing
#
# [687 rows x 2 columns]

# %% [markdown]
# This method works fine but the only problem with this it it creates a new category `Missing`. If count of missing values is higher than other known categories than `Missing`category will impact the result more that will leads to an bad performing model.
#
# To prevent this problem we can create a new feature containing information about missing values, where 1 will represent a missing value.

# %% [markdown]
# ## METHOD 7: Capturing Missing Values with new feature.
#
# It works well if the data are not missing completely at random.

# %%
import numpy as np
titanic['Age_nan']=np.where(titanic['Age'].isnull(),1,0)

# %%
### STEP 1: Creating a new feature
titanic['Cabin_nan']=np.where(titanic['Cabin'].isnull(),1,0)

# %%
titanic.iloc[:5][['Cabin','Cabin_nan']]
# Out:
#   Cabin  Cabin_nan
# 0   NaN          1
# 1   C85          0
# 2   NaN          1
# 3  C123          0
# 4   NaN          1

# %% [markdown]
# Once a new feature is added we can make use of any method to fill missing values.

# %%
titanic['Cabin'].mode()[0]
# Out:
# 'B96 B98'

# %%
titanic['Cabin'].fillna(titanic['Cabin'].mode()[0])
# Out:
# 0      B96 B98
# 1          C85
# 2      B96 B98
# 3         C123
# 4      B96 B98
#         ...
# 886    B96 B98
# 887        B42
# 888    B96 B98
# 889       C148
# 890    B96 B98
# Name: Cabin, Length: 891, dtype: object

# %% [markdown]
# We can try same for numerical column `Age` as well.

# %%
titanic['Age_nan']=np.where(titanic['Age'].isnull(),1,0)

# %%
titanic[['Age','Age_nan']]
# Out:
#       Age  Age_nan
# 0    22.0        0
# 1    38.0        0
# 2    26.0        0
# 3    35.0        0
# 4    35.0        0
# ..    ...      ...
# 886  27.0        0
# 887  19.0        0
# 888   NaN        1
# 889  26.0        0
# 890  32.0        0
#
# [891 rows x 2 columns]

# %% [markdown]
# All above methods we have discussed makes use of manual approach to find missing values and then fill using fillna. There are some advanced methods as well that makes use of machine learning models to predict missing values.
#
# Let's see some of the most famous technique of predicting missing values using machine learning.

# %% [markdown]
# ## METHOD 8: KNN Imputer
#
# In this technique, we predict missing values using an algorithm that uses the values of nearby data points to impute, or predict, missing values. KNN stands for K-Nearest Neighbors, with K referring to the (user-defined) number of neighbors the algorithm will take into account.
#
# KNN only works with numerical data. In some cases, however, non-numerical (e.g., categorical) data may be converted to numerical data for use with the KNN Imputer as well. We can also use the KNN Imputer with multiple features (or columns) at once.

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare  ... Age_median Age_mode  Embarked_mode  \
# 0        0         A/5 21171   7.2500  ...       22.0     22.0              S
# 1        0          PC 17599  71.2833  ...       38.0     38.0              C
# 2        0  STON/O2. 3101282   7.9250  ...       26.0     26.0              S
# 3        0            113803  53.1000  ...       35.0     35.0              S
# 4        0            373450   8.0500  ...       35.0     35.0              S
# ..     ...               ...      ...  ...        ...      ...            ...
# 886      0            211536  13.0000  ...       27.0     27.0              S
# 887      0            112053  30.0000  ...       19.0     19.0              S
# 888      2        W./C. 6607  23.4500  ...       28.0     24.0              S
# 889      0            111369  30.0000  ...       26.0     26.0              C
# 890      0            370376   7.7500  ...       32.0     32.0              Q
#
#      Age_random_sample  Age_end_distribution Age_0  Age_100  Cabin_Missing  \
# 0                 22.0              22.00000  22.0     22.0        Missing
# 1                 38.0              38.00000  38.0     38.0            C85
# 2                 26.0              26.00000  26.0     26.0        Missing
# 3                 35.0              35.00000  35.0     35.0           C123
# 4                 35.0              35.00000  35.0     35.0        Missing
# ..                 ...                   ...   ...      ...            ...
# 886               27.0              27.00000  27.0     27.0        Missing
# 887               19.0              19.00000  19.0     19.0            B42
# 888               42.0              73.27861   0.0    100.0        Missing
# 889               26.0              26.00000  26.0     26.0           C148
# 890               32.0              32.00000  32.0     32.0        Missing
#
#      Age_nan  Cabin_nan
# 0          0          1
# 1          0          0
# 2          0          1
# 3          0          0
# 4          0          1
# ..       ...        ...
# 886        0          1
# 887        0          0
# 888        1          1
# 889        0          0
# 890        0          1
#
# [891 rows x 23 columns]

# %%
df = titanic[["Survived", "Pclass", "Sex", "SibSp", "Parch", "Fare", "Age"]]
df["Sex"] = [1 if x=="male" else 0 for x in df["Sex"]]
# Out:
# C:\Users\BINPAT\AppData\Local\Temp\ipykernel_7100\4162798624.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sex"] = [1 if x=="male" else 0 for x in df["Sex"]]

# %%
### Defining Cols
cols = ['Age','Survived']

### Defining KNN imputer with neighbors
from sklearn.impute import KNNImputer
knn = KNNImputer(n_neighbors=5)

knn.fit_transform(df[cols])
# Out:
# array([[22. ,  0. ],
#        [38. ,  1. ],
#        [26. ,  1. ],
#        ...,
#        [30.1,  0. ],
#        [26. ,  1. ],
#        [32. ,  0. ]])

# %%
df2 = pd.DataFrame(knn.transform(df[cols]),columns=['Age', 'Survived'])

# %%
df2
# Out:
#       Age  Survived
# 0    22.0       0.0
# 1    38.0       1.0
# 2    26.0       1.0
# 3    35.0       1.0
# 4    35.0       0.0
# ..    ...       ...
# 886  27.0       0.0
# 887  19.0       1.0
# 888  30.1       0.0
# 889  26.0       1.0
# 890  32.0       0.0
#
# [891 rows x 2 columns]

# %%
titanic['Age_KNN'] = df2['Age']

# %%
titanic[titanic.Age.isna()][['Age','Age_KNN']]
# Out:
#      Age  Age_KNN
# 5    NaN     30.1
# 17   NaN     27.0
# 19   NaN     27.0
# 26   NaN     30.1
# 28   NaN     27.0
# ..   ...      ...
# 859  NaN     30.1
# 863  NaN     30.1
# 868  NaN     30.1
# 878  NaN     30.1
# 888  NaN     30.1
#
# [177 rows x 2 columns]

# %% [markdown]
# ## METHOD 9: Predicting NAN values using Linear Regression

# %%
titanic.Age.head(8)
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# Name: Age, dtype: float64

# %%
train_data = df[df['Age'].notna()]
test_data = df[df["Age"].isnull()]

X_train= train_data.drop('Age',axis=1)
y_train = train_data['Age']

X_test = test_data.drop('Age',axis=1)
y_test = test_data['Age']

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
y_pred
# Out:
# array([29.07080066, 30.10833306, 22.44685065, 29.08927347, 22.43705181,
#        29.07922599, 32.43692984, 22.43898701, 22.15615704, 29.07922599,
#        29.07691632, 24.96460346, 22.43898701, 20.8713251 , 37.80993305,
#        44.85950626, 17.21443083, 29.07922599, 29.07691632, 22.43842532,
#        29.07691632, 29.07691632, 29.07922599, 22.14798185, 18.1926178 ,
#        29.07691632, 29.08140983, 17.39852793, 27.61791252, 29.08796287,
#        29.06774208, -5.49189866, 36.98755908, 44.88640441, 15.9929439 ,
#        -5.20126796, 37.01068094, 44.52580031, 18.32218064, 29.08140983,
#        22.43898701, -5.49189866, 25.08068578, 29.07922599, 16.2835746 ,
#        29.37503621, 25.27089854, 18.32218064, 29.08889901, 37.44600929,
#        29.08140983, 29.37204054, 44.81038921, 22.43898701, 37.23610531,
#        44.88528103, 44.85950626, 37.88482487, 22.43898701, 13.91474356,
#        30.40869971, 29.07691632, 36.97144531, -5.49189866, 14.20537427,
#        32.62971335, 29.07922599, 18.31319362, 44.75047576, 29.08927347,
#        22.43705181, 22.43705181, 24.96460346, 22.44678774, 22.43898701,
#        33.40078751, 29.07922599, 29.08172138, 16.2835746 , 29.07922599,
#        29.09476604, 37.23610531, 29.36754703, 29.07922599, 29.08889901,
#        29.08140983, 18.31319362, 22.14292665, 24.89769961, 29.07691632,
#        33.85475624, 29.08140983, 29.07691632, 37.23610531, 29.08178429,
#        29.08889901, 44.49584359, 37.23610531, 16.2835746 , 24.89769961,
#        28.98093048, 28.97131886, 29.37384993, 37.9439894 , 29.07691632,
#        28.83576467, 29.08927347, 29.08921056, 41.95282906, 29.08921056,
#        20.57832539, 28.98030588, 30.09541422, 29.08022355, 41.86676638,
#        29.08140983, 29.07691632, 29.36754703, 29.08921056, 22.43898701,
#        25.27083713, 29.06699316, 29.07691632, 27.73018734, 30.0993965 ,
#        29.08927347, 29.07922599, 44.63963587, 29.09189469, 18.32218064,
#        29.08140983, 29.08165997, 45.27471847, 24.95561644, 21.41822401,
#        29.0844055 , 29.07922599, 22.43780073, 29.07922599, 29.08103537,
#        33.85269671, 37.23610531, 29.36623642, 21.41822401, 22.43923715,
#        17.21443083, 44.87704293, 28.96532752, 22.43917424, 37.23610531,
#        29.07922599, 29.07922599, 37.89231405, 28.98030588, 44.68157529,
#        24.83504062, 29.08927347, 29.08140983, 29.08159706, 23.20367227,
#        29.08140983, -5.20126796, 44.81494563, 45.27471847, 29.09339252,
#        28.35127753, 22.1483563 , 29.08921056, 29.07691632, 37.89680756,
#        -5.49189866, 33.29693653, 29.08921056, -5.20126796, 29.0551977 ,
#        29.07922599, 23.49430298])

# %%
a = y_train.to_list()
b = list(y_pred)
a.extend(b)

# %%
titanic['Age_LR'] = a

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare  ... Embarked_mode Age_random_sample  \
# 0      0         A/5 21171   7.2500  ...             S              22.0
# 1      0          PC 17599  71.2833  ...             C              38.0
# 2      0  STON/O2. 3101282   7.9250  ...             S              26.0
# 3      0            113803  53.1000  ...             S              35.0
# 4      0            373450   8.0500  ...             S              35.0
# 5      0            330877   8.4583  ...             Q              42.0
# 6      0             17463  51.8625  ...             S              54.0
# 7      1            349909  21.0750  ...             S               2.0
# 8      2            347742  11.1333  ...             S              27.0
# 9      0            237736  30.0708  ...             C              14.0
#
#    Age_end_distribution  Age_0  Age_100 Cabin_Missing  Age_nan  Cabin_nan  \
# 0              22.00000   22.0     22.0       Missing        0          1
# 1              38.00000   38.0     38.0           C85        0          0
# 2              26.00000   26.0     26.0       Missing        0          1
# 3              35.00000   35.0     35.0          C123        0          0
# 4              35.00000   35.0     35.0       Missing        0          1
# 5              73.27861    0.0    100.0       Missing        1          1
# 6              54.00000   54.0     54.0           E46        0          0
# 7               2.00000    2.0      2.0       Missing        0          1
# 8              27.00000   27.0     27.0       Missing        0          1
# 9              14.00000   14.0     14.0       Missing        0          1
#
#    Age_KNN  Age_LR
# 0     22.0    22.0
# 1     38.0    38.0
# 2     26.0    26.0
# 3     35.0    35.0
# 4     35.0    35.0
# 5     30.1    54.0
# 6     54.0     2.0
# 7      2.0    27.0
# 8     27.0    14.0
# 9     14.0     4.0
#
# [10 rows x 25 columns]

# %%
titanic[titanic.Age.isna()][['Age','Age_LR']]
# Out:
#      Age     Age_LR
# 5    NaN  54.000000
# 17   NaN  35.000000
# 19   NaN  15.000000
# 26   NaN  28.000000
# 28   NaN  21.000000
# ..   ...        ...
# 859  NaN  17.214431
# 863  NaN  37.236105
# 868  NaN  44.681575
# 878  NaN  29.093393
# 888  NaN  29.055198
#
# [177 rows x 2 columns]

# %% [markdown]
# ## Thanks For Reading
# I hope You Found Someting useful.
